# %% [markdown]
# # Import

# %%
import os
import sys
# %matplotlib inline
import matplotlib.pylab as plt
import pandas as pd

# %% [markdown]
# # Plot wave function

# %%
df_grid = pd.read_csv("grid.csv")
df_gto_et_1 = pd.read_csv("gto_et_one/w1/wf.csv")
df_gto_et_2 = pd.read_csv("gto_et_two/w1/wf.csv")

# %%
plt.plot(df_grid['r'], df_grid['re_y'], 'k--', label='Grid')
plt.plot(df_gto_et_1['r'], df_gto_et_1['re_y'], 'r', label='ET+One')
plt.plot(df_gto_et_2['r'], df_gto_et_2['re_y'], 'b', label='ET+Two')
plt.xlim(0, 20)
# Out:
# (0, 20)

# %% [markdown]
# # Optimization note (2016/11/11)

# %% [markdown]
# gto_2/search/filtered.csv 結果を見ると、収束点が三種類観測された。それぞれの点に対して一点計算を行い、展開係数および波動関数を調べる。
